# %%
import os
import random
import cv2
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
TRAIN_DIR = 'test'
CATEGORIES = []
for c in os.listdir(TRAIN_DIR):
    CATEGORIES.append(c)
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
TRAIN_DATA = []
for c in CATEGORIES:
    path = os.path.join(TRAIN_DIR,c)
    class_num = CATEGORIES.index(c)
    for img in tqdm(os.listdir(path)):
        img_arr = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        TRAIN_DATA.append([img_arr, class_num])
print(len(TRAIN_DATA))
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 28121.38it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28158.76it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 29226.97it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28420.74it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28572.33it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 27060.72it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 27392.45it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28502.82it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 27565.27it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 27026.55it/s]
# 10000

# %%
random.shuffle(TRAIN_DATA)

# %%
plt.figure(figsize=(20,10))

for i in range(50):
    plt.subplot(5,10,i+1)
    plt.imshow(TRAIN_DATA[i][0], cmap='gray')
    plt.xlabel(CATEGORIES[TRAIN_DATA[i][1]])
    plt.xticks([])
    plt.yticks([])
    if i==50:
        break
plt.show()
